# %%
import os
from pathlib import Path
import csv
import matplotlib.pyplot as plt

def visualize_plot(csv_path):
    t = []
    velocity = []

    with open(csv_path, 'r') as log_result:
        lines = csv.reader(log_result, delimiter=',')
        header = []

        for index, row in enumerate(lines):
            if index != 0:
                t.append(float(row[0]))
                velocity.append(float(row[3]))
    
    plt.plot(t, velocity)
    plt.grid(visible=True)
    plt.ylim([0,110])

    plt.show()

# %%
import numpy as np
R = np.diag([0.001, 0.001, 1.0, 0.000001])
Q = np.diag([0.3, 0.3, 1.0, 0.05, 7.5, 7.5, 0.000001])

cur_file_path = os.path.abspath('')
csv_root_path = Path(cur_file_path)
csv_file_name = "20240816_155039_global.csv"

csv_path = os.path.join(csv_root_path, csv_file_name)

visualize_plot(csv_path)
# x y R 높이면 위치 수렴 늦어짐

# %%
import numpy as np
R = np.diag([0.001, 0.001, 1.0, 0.000001])
Q = np.diag([0.3, 0.3, 1.0, 0.05, 7.5, 7.5, 0.000001])

cur_file_path = os.path.abspath('')
csv_root_path = Path(cur_file_path)
csv_file_name = "20240816_155131_global.csv"

csv_path = os.path.join(csv_root_path, csv_file_name)

visualize_plot(csv_path)
# x y R 높이면 위치 수렴 늦어짐
